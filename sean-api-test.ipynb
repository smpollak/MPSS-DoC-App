# %% [markdown]
# # API Testing
#
# Seeing if we can pull data from our APIs

# %% [markdown]
# ## IMPORTS

# %%
import requests
import pandas as pd
import json
from io import StringIO

# %% [markdown]
# ## GINI Data

# %%
gini_url = "https://api.worldbank.org/v2/country/usa/indicator/SI.POV.GINI?format=json"

# %%
# should get a response of 200 here
response = requests.get(gini_url)
print(response.status_code)
# Out:
# 200

# %%
# should show the shape of json data and some metadata
data = response.json()
print(type(data), len(data))
print(json.dumps(data[0], indent=2))
# Out:
# <class 'list'> 2
# {
#   "page": 1,
#   "pages": 2,
#   "per_page": 50,
#   "total": 65,
#   "sourceid": "2",
#   "lastupdated": "2025-04-15"
# }

# %%
# Unboxing the data into a pd dataframe
gini_df = pd.DataFrame(data[1]) # the data should be located within the second index of the json response
gini_df['indicator'] = gini_df['indicator'].apply(lambda d: d['value']) # extract the 'value' element from each nested dict
gini_df['country']   = gini_df['country'].apply(lambda d: d['value'])
gini_df = gini_df[['date', 'country', 'countryiso3code', 'indicator','value']] # selecting columns to keep
gini_df.head(8)
# Out:
#    date        country countryiso3code   indicator  value
# 0  2024  United States             USA  Gini index    NaN
# 1  2023  United States             USA  Gini index    NaN
# 2  2022  United States             USA  Gini index   41.3
# 3  2021  United States             USA  Gini index   39.7
# 4  2020  United States             USA  Gini index   39.7
# 5  2019  United States             USA  Gini index   41.5
# 6  2018  United States             USA  Gini index   41.4
# 7  2017  United States             USA  Gini index   41.2

# %% [markdown]
# ## Union Density Data

# %%
union_density_url = "https://sdmx.oecd.org/public/rest/data/OECD.ELS.SAE,DSD_TUD_CBC@DF_TUD,/all?startPeriod=2000&endPeriod=2025&dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

# %%
# Define API query URL (CSV with labels format)

response = requests.get(union_density_url)
union_density_df = pd.read_csv(StringIO(response.text)) #stringio makes it "appear" like a csv to pandas
union_density_df[union_density_df['Reference area']=='United States']
# Out:
#     STRUCTURE                          STRUCTURE_ID       STRUCTURE_NAME  \
# 288  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 289  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 290  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 291  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 292  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 293  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 294  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 295  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 296  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 297  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 298  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 299  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 300  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 301  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 302  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 303  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 304  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 305  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 306  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 307  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
# 308  DATAFLOW  OECD.ELS.SAE:DSD_TUD_CBC@DF_TUD(1.0)  Trade union density
#
#     ACTION REF_AREA Reference area MEASURE              Measure UNIT_MEASURE  \
# 288      I      USA  United States     TUD  Trade union density       PT_SAL
# 289      I      USA  United States     TUD  Trade union density       PT_SAL
# 290      I      USA  United States     TUD  Trade union density       PT_SAL
# 291      I      USA  United States     TUD  Trade union density       PT_SAL
# 292      I      USA  United States     TUD  Trade union density       PT_SAL
# 293      I      USA  United States     TUD  Trade union density       PT_SAL
# 294      I      USA  United States     TUD  Trade union density       PT_SAL
# 295      I      USA  United States     TUD  Trade union density       PT_SAL
# 296      I      USA  United States     TUD  Trade union density       PT_SAL
# 297      I      USA  United States     TUD  Trade union density       PT_SAL
# 298      I      USA  United States     TUD  Trade union density       PT_SAL
# 299      I      USA  United States     TUD  Trade union density       PT_SAL
# 300      I      USA  United States     TUD  Trade union density       PT_SAL
# 301      I      USA  United States     TUD  Trade union density       PT_SAL
# 302      I      USA  United States     TUD  Trade union density       PT_SAL
# 303      I      USA  United States     TUD  Trade union density       PT_SAL
# 304      I      USA  United States     TUD  Trade union density       PT_SAL
# 305      I      USA  United States     TUD  Trade union density       PT_SAL
# 306      I      USA  United States     TUD  Trade union density       PT_SAL
# 307      I      USA  United States     TUD  Trade union density       PT_SAL
# 308      I      USA  United States     TUD  Trade union density       PT_SAL
#
#              Unit of measure  TIME_PERIOD  Time period  OBS_VALUE  \
# 288  Percentage of employees         2000          NaN       12.9
# 289  Percentage of employees         2001          NaN       12.9
# 290  Percentage of employees         2002          NaN       12.8
# 291  Percentage of employees         2003          NaN       12.4
# 292  Percentage of employees         2004          NaN       12.0
# 293  Percentage of employees         2005          NaN       12.0
# 294  Percentage of employees         2006          NaN       11.5
# 295  Percentage of employees         2007          NaN       11.6
# 296  Percentage of employees         2008          NaN       11.9
# 297  Percentage of employees         2009          NaN       11.8
# 298  Percentage of employees         2010          NaN       11.4
# 299  Percentage of employees         2011          NaN       11.3
# 300  Percentage of employees         2012          NaN       10.8
# 301  Percentage of employees         2013          NaN       10.8
# 302  Percentage of employees         2014          NaN       10.7
# 303  Percentage of employees         2015          NaN       10.6
# 304  Percentage of employees         2016          NaN       10.3
# 305  Percentage of employees         2017          NaN       10.3
# 306  Percentage of employees         2018          NaN       10.1
# 307  Percentage of employees         2019          NaN        9.9
# 308  Percentage of employees         2020          NaN       10.3
#
#      Observation value OBS_STATUS Observation status  UNIT_MULT  \
# 288                NaN          A       Normal value          0
# 289                NaN          A       Normal value          0
# 290                NaN          A       Normal value          0
# 291                NaN          A       Normal value          0
# 292                NaN          A       Normal value          0
# 293                NaN          A       Normal value          0
# 294                NaN          A       Normal value          0
# 295                NaN          A       Normal value          0
# 296                NaN          A       Normal value          0
# 297                NaN          A       Normal value          0
# 298                NaN          A       Normal value          0
# 299                NaN          A       Normal value          0
# 300                NaN          A       Normal value          0
# 301                NaN          A       Normal value          0
# 302                NaN          A       Normal value          0
# 303                NaN          A       Normal value          0
# 304                NaN          A       Normal value          0
# 305                NaN          A       Normal value          0
# 306                NaN          A       Normal value          0
# 307                NaN          A       Normal value          0
# 308                NaN          A       Normal value          0
#
#     Unit multiplier  DECIMALS Decimals
# 288           Units         1      One
# 289           Units         1      One
# 290           Units         1      One
# 291           Units         1      One
# 292           Units         1      One
# 293           Units         1      One
# 294           Units         1      One
# 295           Units         1      One
# 296           Units         1      One
# 297           Units         1      One
# 298           Units         1      One
# 299           Units         1      One
# 300           Units         1      One
# 301           Units         1      One
# 302           Units         1      One
# 303           Units         1      One
# 304           Units         1      One
# 305           Units         1      One
# 306           Units         1      One
# 307           Units         1      One
# 308           Units         1      One
